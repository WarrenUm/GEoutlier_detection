# %%
import pandas as pd
import numpy as np
from osrs_fcns import *

# %%
#load price data, convert timestamp to datetime. Save each item to a new dataframe. Then, update each dataframe for each item with the newest price.

# %%
#load item_list

items_list = pd.read_csv('latest_osrs_items2022-03-07 12-41-21.csv')

# %%
items_list
# Out:
#                                                 examine     id  members  \
# 0     Fabulously ancient mage protection enchanted i...  10344     True
# 1     A beautifully crafted axe, shaped by ancient s...  20011     True
# 2     A beautifully crafted bow carved by ancient ar...  12424     True
# 3           A beautiful cloak woven by ancient tailors.  12437     True
# 4     A fabulously ancient vine cloak as worn by the...  23345     True
# ...                                                 ...    ...      ...
# 3877                       A pile of Zombie Ogre bones.   4812     True
# 3878                                Get a head in life.  19912     True
# 3879                        Teleports you to Zul-Andra.  12938     True
# 3880                         Flakes of toxic snakeskin.  12934     True
# 3881                                  A powerful staff.  22647     True
#
#        lowalch    limit   value  highalch                               icon  \
# ...

# %%
recent_prices = update_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-09ffedcb7a77> in <module>
# ----> 1 recent_prices = update_data()
#
# ~\Documents\Data Science\GEoutlier_detection\notebooks\osrs_fcns.py in update_data()
#      36     five_min_data.id = five_min_data.id.astype('int64')
#      37
# ---> 38     latest_items = pd.read_csv('latest_osrs_items.csv')
#      39
#      40     all_w_latest = latest_items.merge(five_min_data,on='id')
#
# ...

# %%
item_ids = list(recent_prices.id.unique())

# %%
#make separate dataframes named by item_id

for item_id in item_ids:
    #check if csv for item exists in dir
    
    #load existing csv
    
    #add recent data
    
    #if not, make new csv 
    # addw recent data
    #columns are: id, avgHighPrice, highPriceVolume, avgLowPrice, lowPriceVolume, timestamp
    
    #save
