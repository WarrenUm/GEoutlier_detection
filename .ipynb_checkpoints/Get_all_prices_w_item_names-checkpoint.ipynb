# %%
#fetching data from the db and formatting it into a dataframe. Also merging on the item id to get the name.

# %%
import sqlite3
from sqlite3 import Error
import pandas as pd

# %%
def get_items():
    conn = sqlite3.connect('geitems.db')
    cur = conn.cursor()
    cur.execute("""SELECT item_id, name FROM items""")
    response = cur.fetchall()
    df = pd.DataFrame(response,columns=['item_id','name'])
    conn.close()
    return df

# %%
df = get_items()

# %%
df
# Out:
#       item_id                           name
# 0       10344                 3rd age amulet
# 1       20011                    3rd age axe
# 2       12424                    3rd age bow
# 3       12437                  3rd age cloak
# 4       23345          3rd age druidic cloak
# ...       ...                            ...
# 3877     4812                    Zogre bones
# 3878    19912  Zombie head (Treasure Trails)
# 3879    12938             Zul-andra teleport
# 3880    12934                Zulrah's scales
# 3881    22647                 Zuriel's staff
#
# [3882 rows x 2 columns]

# %%
def get_prices():
    conn = sqlite3.connect('geitems.db')
    cur = conn.cursor()
    cur.execute("""SELECT * FROM prices""")
    response = cur.fetchall()
    df = pd.DataFrame(response,columns=['id','item_id','timestamp','avgHighPrice','highPriceVolume','avgLowPrice','lowPriceVolume'])
    conn.close()
    return df

# %%
price_df = get_prices()

# %%
price_df
# Out:
#           id  item_id   timestamp  avgHighPrice  highPriceVolume  avgLowPrice  \
# 0          1     9998  1647194100        6750.0                4       5990.0
# 1          2     9998  1647194400        6934.0               31          NaN
# 2          3     9998  1647194700        6998.0                2       5500.0
# 3          4    10010  1646679000          15.0                1          NaN
# 4          5    10029  1646679000           6.0                3          NaN
# ...      ...      ...         ...           ...              ...          ...
# 15503  15504      987  1647198300           NaN                0       9474.0
# 15504  15505      989  1647198300       19934.0                1      19393.0
# 15505  15506       99  1647198300        9784.0              108       9600.0
# 15506  15507      991  1647198300        3000.0                1          NaN
# 15507  15508      993  1647198300           NaN                0      39126.0
#
#        lowPriceVolume
# ...

# %%
def join_item_names(item_df,price_df):
    joined_df = item_df.join(price_df,on='item_id')
    return joined_df

# %%
item_df.merge()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8e259d50cad3> in <module>
# ----> 1 joined = join_item_names(df,price_df)
#
# <ipython-input-12-7c3fb36f8276> in join_item_names(item_df, price_df)
#       1 def join_item_names(item_df,price_df):
# ----> 2     joined_df = item_df.join(price_df,on='item_id')
#       3     return joined_df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# ...
